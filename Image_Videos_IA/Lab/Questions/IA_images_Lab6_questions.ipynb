# %% [markdown]
# #**Session 6 LAB: Face Detection, Recognition, Emotion Detection, Tracking & Background Removal**
#
# In this lab, you will explore how machine learning models interpret facial images by:
# - Reconstructing your face using **PCA & Eigenfaces**
# - Comparing identity similarity using **FaceNet**
# - Detecting emotions from facial expressions using the **FER** library
#
# We'll use real pictures of you with different expressions and occlusion to analyze robustness and performance.
#
# ---
#
# So first take a selfie of you:
#
# - Normal
# - Sad
# - Happy
# - Surprise
# - Other
# - Hide a part of your face

# %%
# !pip install fer facenet-pytorch opencv-python matplotlib scikit-learn

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# %%
img = files.upload()
# Out:
#      <input type="file" id="files-5dd08572-12b6-466c-a1f9-0e0f10d20319" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5dd08572-12b6-466c-a1f9-0e0f10d20319">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #**Part 1 – PCA & Eigenfaces**
#
# 1. **Load** the Labeled Faces in the Wild (LFW) dataset with `fetch_lfw_people`.
# 2. **Split** it into a training and test set (75 % / 25 %) so we can “learn” eigenfaces only on the training set.
# 3. **Train (fit) a PCA model** with 150 components on the **flattened** training faces.
# 4. **Project** your own `normal.jpeg` into that PCA space to obtain its 150-D representation.
# 5. **Reconstruct** your face by mapping the 150-D vector back to image space (inverse transform) and visualise the differences.
# 6. **Compute Euclidean distances** between your projected face and all projected training faces.
# 7. **Identify the closest training face** (smallest distance) and display the LFW person who matches best.

# %%
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import euclidean_distances
from facenet_pytorch import MTCNN
from skimage import io, color, transform
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1) Load and split LFW
# Out:
# 50 37
# (1288, 1850)

# %%
# 2) Train PCA on training faces


# 3) Detect, crop, resize *your* face
image_path='normal.jpeg'



mtcnn = MTCNN(keep_all=False, margin=20)
# Out:
# (160, 160, 3)
# (50, 37)
# (1850,)

# %%
# 4) Apply PCA to your cropped selfie


# 5) Derive distances to search for similarities


# 6) Show all the images

# %% [markdown]
# #**Part 2 - FaceNet Similarity: Normal vs Occlusion**
#
# **Task**
#
# - Use FaceNet to compute embeddings of normal.jpeg and occulation.jpeg.
#
# - Compare them with cosine similarity and Euclidean distance.

# %%
from facenet_pytorch import InceptionResnetV1, MTCNN
from PIL import Image
import torch
# Out:
# Cosine similarity: 0.4888
# Euclidean distance: 1.0111

# %% [markdown]
# #**Part 3 - Emotion Recognition with FER**
#
# **Tasks**
#
# - Load 4 facial expressions.
#
# - Detect and visualize the predicted emotion and probabilities.

# %%
from fer import FER
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# #**Part 4 - Background Subtraction & Object Tracking**
#
# **Tasks**
#
# Use the video "video_umbrella"
#
# - Subtract the background to isolate moving objects
#
# - Detect and track umbrellas across frames
#
# - Visualize their path by drawing a motion trail

# %% [markdown]
# **Step 1:** Load the video and show the first 5 frames

# %%
video = files.upload()
# Out:
#      <input type="file" id="files-a53d4ef4-8bf9-4de9-9b90-36064eba6cd3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a53d4ef4-8bf9-4de9-9b90-36064eba6cd3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
cap = cv2.VideoCapture("video_umbrella.mp4")

for i in range(5):

# %% [markdown]
# **Step2: Use OpenCV's background subtractor to isolate moving objects an save a video and display it too**

# %% [markdown]
# **Step3: Track the Umbrella and Draw Path**
#
# - Use YoLO to detect the umbrella
# - ByteTrack
# - Store the centroid (cx, cy) in a trail dictionary by ID
# - Draw lines using cv2.line()

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2
from collections import defaultdict
import numpy as np
import random


video_in = "video_umbrella.mp4"
video_out = "umbrella_yolo_tracking.mp4"
model_path = "yolov8n.pt"

# ---------------------------------------------------------------------------
# Initialisation
# ---------------------------------------------------------------------------
model = YOLO(model_path)

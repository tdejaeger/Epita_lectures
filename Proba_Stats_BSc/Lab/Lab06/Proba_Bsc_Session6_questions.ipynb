# %% [markdown]
# # Session 6 Lab

# %% [markdown]
# ## Part A —  Basic Conditionals

# %%
from google.colab import files
import pandas as pd
uploaded = files.upload()  # choose smoker_flu.csv from your laptop
df = pd.read_csv(next(iter(uploaded)))
df.head()

# %% [markdown]
# Using the file smoker_flu.csv, compute:
#
# - P(A)
# - P(B)
# - P(A|B)
# - P(B|A)
# - P(B|Ac)
#
# Is flu independent of smoking?

# %%
#First you can transform the data to have the count using pandas.crosstab
counts = pd.crosstab()
display(counts)

# %%
#Now that you have the counts, you can obtain the proba
probs =
display(probs)

# %%
#Now derive the probability of the event A and B
#Can use use .loc sometimes

P_A =
P_B =


print("P(A) =", P_A)
print("P(B) =", P_B)

# %%
P_AnB=
P_BnA=P_AnB

P_BnAc=

P_A_given_B = P_AnB / P_B
P_B_given_A = P_BnA / P_A
P_B_given_Ac = P_BnAc / (1-P_A)


print("P(A|B) =", P_A_given_B)
print("P(B|A) =", P_B_given_A)
print("P(B|A^c) =", P_B_given_Ac)

# %% [markdown]
# ## Part B — Convergence of Sample Proportions
#
#  Suppose a coin has probability p of falling heads
# up. If we flip the coin many times, we would expect the proportion of
# heads to be near p.
#
# - Take p = .3 and n = 1, 000 and simulate n coin flips.
# - Plot the proportion of heads as a function of n.
# - Repeat for p = .03.
#
# What do you remark?

# %%
import numpy as np, random
import matplotlib.pyplot as plt

def run_simulation(p, n):

  #Generate n random number
  nums =

  #if nums <p toss=1 otherwise 0
  toss=
  #Take the cumulative sum and divide by the number of event
  nevent=np.arange(1,n+1)
  running=/

  #do a figure with title, x,y label and an horizontal line (axhline) for p
  plt.figure()

  plt.show()

#Answer the questions

# %% [markdown]
# ## Part C — Simulating Conditional Probabilities
#
# Here we will get some experience simulating probabilities. Consider a fair die and the two event A and B defined by:
#
# - **A = {2, 4, 6}**
# - **B = {1, 2, 3, 4}**.
#
# First derive theorical probabilities
#
# - **P(A)**
# - **P(B)**
# - and **P(A∩B)**.
#
# Are A and B independent?
#
#
# **Simulation**
#
# - Create a die and compare the probability you obtain with the theoritical ones.
#
# If you want a difference smaller than 1%, what is the minumum number of simulations you need?

# %%
# Theorical

A = {2,4,6}
B = {1,2,3,4}

#Derive the different probabilities
P_A=
P_B=

P_AnB=

#Print the values


#Check if A and B are independent if it is the case print it

# %%
#Create a simulation

import random
#Create a fake die than you cna draw N times using randint
def die(N):
  rolls=
  return rolls

def simulation(N):

  #Count the number of occurences for A and B and AnB
  A_occ =
  B_occ =
  AB_occ =

  #Obtain the proba for A, B, AnB simulated
  Phat_A =
  Phat_B =
  Phat_AnB =

  #Print
  print("Simu:   Probability of A: %0.3f"%Phat_A)
  print("Simu:   Probability of B: %0.3f"%Phat_B)
  print("Simu:   Probability of AnB: %0.3f"%Phat_AnB)

  #Compare the simulated values and the theortical ones.
  # If the absolute difference is smaller than 1% for the 3, print that you have enough simulations
  P_A=
  P_B=
  P_AnB=

  if :
    print('You simulated enough with N=%s'%N)
  else:
    print('You need to simulate more')

#Try different number and find the minimum number of simulation (just the order of magnitudes)

# %% [markdown]
# Now, redo everything but for two events C and D that are not independent.
#
# First, you need to find those events

# %%
C =
D =

#Derive the different probabilities
P_C=
P_D=

P_CnD=

#Check if C and D are independent or not

#Compare the minium number of simulation to have a difference of 1% as it was done previously.

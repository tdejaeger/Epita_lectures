# %% [markdown]
# # Matplotlib & Seaborn Tutorial
#
# This notebook will guide you through basic and advanced plotting techniques using **Matplotlib** and **Seaborn**.
#
# ---
#
# ## Sections:
# 1. Basic Plots (Matplotlib & Seaborn)
# 2. Advanced Visualizations (Seaborn)
#
# Let's begin by importing necessary libraries.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Set default Seaborn theme
sns.set_theme()

# %% [markdown]
# ## 1. Basic Plots

# %% [markdown]
# ### Histogram

# %%
#Maptlotlib
data = np.random.randn(1000)
plt.hist(data, bins=30, color='skyblue', edgecolor='white')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.tick_params(left=True, bottom=True)

plt.show()

# %%
#seaborn
ax = sns.histplot(data, bins=30, kde=True)

ax.set_title('Histogram')
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.tick_params(left=True, bottom=True)

plt.show()

# %% [markdown]
# ### Bar Plot

# %%
#Matplotlib
categories = ['A', 'B', 'C']
values = [5, 7, 3]

fig, ax = plt.subplots()
bars = ax.bar(categories, values, color='blue')
# Add numbers on top of each bar
for bar in bars:
    height = int(bar.get_height())
    ax.annotate(f'{height}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5),
                textcoords='offset points',
                ha='center', va='bottom')

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Remove left and bottom spines too
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.tick_params(left=False, bottom=False)
ax.set_yticklabels([])

plt.xlabel('Category')
plt.title('Bar plot', pad=20) #pad to move the title upper, otherwise overlap with number
plt.show()

# %%
#Matplotlib
categories = ['A', 'B', 'C']
values = [5, 7, 3]

fig, ax = plt.subplots()
bars = ax.barh(categories, values, color='blue')  # ← horizontal bars

# Add numbers on top of each bar
for bar in bars:
    width = int(bar.get_width())
    ax.annotate(f'{width}',
                xy=(width, bar.get_y() + bar.get_height() / 2),
                xytext=(5, 0),
                textcoords='offset points',
                ha='left', va='center')

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Remove left and bottom spines too
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(False)
ax.tick_params(left=False, bottom=False)
ax.set_xticklabels([])

# Labels
plt.ylabel('Category')
plt.title('Bar plot', pad=20) #pad to move the title upper, otherwise overlap with number
plt.show()

# %%
#Seaborn
df = pd.DataFrame({'Category': categories, 'Value': values})
ax = sns.barplot(data=df, x='Category', y='Value')
for bar in ax.patches:
    height = int(bar.get_height())
    ax.annotate(f'{height}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5),
                textcoords='offset points',
                ha='center', va='bottom')

ax.set_title("Seaborn Bar Plot",pad=20)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel(None)
ax.set_yticklabels([])
ax.tick_params(left=False)
sns.despine(left=True, bottom=False)

plt.show()

# %% [markdown]
# ### Count Plot (Seaborn)

# %%
sns.set_style("white")           # Removes the gray background
titanic = sns.load_dataset('titanic')
ax = sns.countplot(data=titanic, x='class')
plt.title('Count of Passengers by Class')
# Add counts on top of bars
for bar in ax.patches:
    height = int(bar.get_height())
    ax.annotate(f'{height}',
                xy=(bar.get_x() + bar.get_width() / 2, height),
                xytext=(0, 5),
                textcoords='offset points',
                ha='center', va='bottom')

# Remove y-axis label and ticks
ax.set_ylabel(None)
ax.set_yticklabels([])
ax.tick_params(left=False)

# Remove spines=border
sns.despine(left=True, bottom=True)
ax.grid(False)
plt.show()

# %%
titanic = sns.load_dataset('titanic')

# Count plot: counts of passengers by class and sex
ax = sns.countplot(data=titanic, x='class', hue='sex')

# Add labels
for bar in ax.patches:
    height = int(bar.get_height())
    if height > 0:
      ax.annotate(f'{height}',
                  xy=(bar.get_x() + bar.get_width() / 2, height),
                  xytext=(0, 5),
                  textcoords='offset points',
                  ha='center', va='bottom')

# Style
ax.set_title("Passenger Count by Class and Sex", pad=20)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_ylabel(None)
ax.set_yticklabels([])
ax.tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %%
titanic = sns.load_dataset('titanic')

# Count plot: counts of passengers by class and sex
ax = sns.countplot(data=titanic, y='class', hue='sex')

# Add labels
for bar in ax.patches:
    width = int(bar.get_width())
    if width > 0:
      ax.annotate(f'{width}',
                  xy=(width, bar.get_y() + bar.get_height() / 2),
                  xytext=(5, 0),
                  textcoords='offset points',
                  ha='left', va='center')

# Style
ax.set_title("Passenger Count by Class and Sex", pad=20)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel(None)
ax.set_xticklabels([])
ax.tick_params(left=False)
sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
#Matplotlib
x = np.random.rand(50)
y = x * 2 + np.random.randn(50) * 0.2
fig, ax = plt.subplots()

ax.scatter(x, y, color='tomato')
ax.tick_params(left=True, bottom=True)
ax.set_title('Scatter Plot')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
df = pd.DataFrame({'x': x, 'y': y})
ax = sns.scatterplot(data=df, x='x', y='y', color='tomato')
ax.set_title('Scatter Plot')
ax.tick_params(left=True, bottom=True)

ax.set_xlabel('x')
ax.set_ylabel('y')

plt.show()

# %%
iris = sns.load_dataset('iris')
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Line Plot

# %%
#Matplotlib
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y, color='purple', marker='o', markersize=2)
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.tick_params(left=True, bottom=True)
plt.show()

# %%
#seaborn
sns.lineplot(x=x, y=y, color='purple', marker='o', markersize=5)

# Customize
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.tick_params(left=True, bottom=True)
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
#Matplotlib
labels = ['Apple', 'Banana', 'Cherry']
sizes = [40, 35, 25]
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Fruit Distribution')
plt.show()

# %% [markdown]
# ### Violin Plot (Seaborn)

# %%
ax=sns.violinplot(data=titanic, x='class', y='fare', legend=False)
ax.tick_params(left=True, bottom=True)
plt.title('Age Distribution by Class')
plt.show()

# %% [markdown]
# ### Boxplot (Seaborn)

# %%
ax=sns.boxplot(data=titanic, x='class', y='fare', legend=False)
ax.tick_params(left=True, bottom=True)

plt.title('Fare by Class')
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(data=titanic, x='class', y='fare',
            width=0.5, fliersize=0, boxprops=dict(alpha=0.4), color='blue')

ax = sns.swarmplot(data=titanic, x='class', y='fare',
                   size=2, color='blue', alpha=0.6)

# Style
ax.set_title('Fare by Passenger Class', fontsize=14, pad=15)
ax.set_xlabel('Class')
ax.set_ylabel('Fare')
ax.tick_params(left=True, bottom=True)
sns.despine()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 13.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py:3399: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 2. Advanced Seaborn Plots

# %% [markdown]
# ### Joint Plot

# %%
sns.jointplot(data=titanic, x='age', y='fare', kind='scatter', hue='sex')

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(data=titanic[['age', 'fare', 'pclass', 'sex']].dropna(), hue='sex', palette='husl')

# %% [markdown]
# ### Heatmap

# %%
corr = titanic.corr(numeric_only=True)
sns.heatmap(corr, annot=False,fmt="0.1f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
corr = titanic.corr(numeric_only=True)
sns.heatmap(corr, annot=True,fmt="0.1f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Exercises

# %%
data = {
    "Entity": [
        "Austria", "Belgium", "Denmark", "Finland", "France", "Germany", "Greece", "Ireland",
        "Italy", "Luxembourg", "Netherlands", "Norway", "Portugal", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"
    ],
    "Percent Electric": [
        "3%", "2%", "2%", "2%", "2%", "2%", "0%", "3%",
        "1%", "2%", "14%", "42%", "3%", "1%", "4%", "4%", "0%", "2%"
    ],
    "Percent Plug-in Hybrid": [
        "1%", "2%", "2%", "5%", "1%", "1%", "0%", "1%",
        "0%", "2%", "1%", "14%", "3%", "1%", "7%", "1%", "0%", "2%"
    ],
    "Percent Hybrid": [
        "4%", "4%", "6%", "12%", "4%", "4%", "5%", "9%",
        "5%", "4%", "6%", "12%", "4%", "8%", "10%", "6%", "3%", "7%"
    ],
    "Percent Gasoline": [
        "53%", "62%", "63%", "62%", "58%", "59%", "68%", "40%",
        "53%", "50%", "71%", "16%", "50%", "58%", "45%", "60%", "46%", "64%"
    ],
    "Percent Diesel": [
        "40%", "31%", "27%", "19%", "35%", "34%", "27%", "46%",
        "41%", "44%", "8%", "16%", "40%", "33%", "34%", "28%", "51%", "27%"
    ]
}

# Create DataFrame
df = pd.DataFrame(data)
df.head()
# Out:
#     Entity Percent Electric Percent Plug-in Hybrid Percent Hybrid  \
# 0  Austria               3%                     1%             4%
# 1  Belgium               2%                     2%             4%
# 2  Denmark               2%                     2%             6%
# 3  Finland               2%                     5%            12%
# 4   France               2%                     1%             4%
#
#   Percent Gasoline Percent Diesel
# 0              53%            40%
# 1              62%            31%
# 2              63%            27%
# 3              62%            19%
# 4              58%            35%

# %% [markdown]
# **Questions**
#
# 1) Create a graph of the types of vehicles driven in Ireland. Why did you choose the type of graph you did? What does the graph tell you about the types of cars people drive in Ireland?
#
# 2) Create a graph of the percentages of vehicles which are electric, plug-in hybrid, or hybrid in each country. Why did you choose the type of graph you did? What does the graph tell you about the usage of electric/hybrid cars across Europe?
#
# 3) Create a graph which compares the types of vehicles driven in Norway and the United Kingdom. Why did you choose the type of graph you did? What does the graph tell you about the differences between Norway and the United Kingdom?

# %%
data_time = {
    "Year": [2013, 2014, 2015, 2016, 2017, 2018, 2019],
    "Electric": ["6%", "13%", "17%", "15%", "19%", "31%", "42%"],
    "Plug-in Hybrid": ["0%", "1%", "5%", "14%", "20%", "18%", "14%"],
    "Hybrid": ["7%", "7%", "7%", "11%", "13%", "11%", "12%"],
    "Gasoline": ["35%", "31%", "30%", "29%", "26%", "23%", "16%"],
    "Diesel": ["53%", "49%", "41%", "31%", "23%", "18%", "16%"]
}

# Create DataFrame
df = pd.DataFrame(data_time)
for col in df.columns[1:]:
    df[col] = df[col].str.replace('%', '').astype(float)
df.head()
# Out:
#    Year  Electric  Plug-in Hybrid  Hybrid  Gasoline  Diesel
# 0  2013       6.0             0.0     7.0      35.0    53.0
# 1  2014      13.0             1.0     7.0      31.0    49.0
# 2  2015      17.0             5.0     7.0      30.0    41.0
# 3  2016      15.0            14.0    11.0      29.0    31.0
# 4  2017      19.0            20.0    13.0      26.0    23.0

# %% [markdown]
# **Questions**
#
# 1) Graph the percentage of fully electric vehicles in Norway for each year since 2013. Explain why you chose the graph that you did.
#
# 2) Improve your graph adding title, subtitle, highlight important things
# https://ourworldindata.org/data-insights/almost-every-new-car-sold-in-norway-is-electric
#
# 3) Create a graph of the percentages of electric (fully electric, plug-in-hybrid, hybrid) and petroleum (gasoline, diesel) in Norway for each year from 2013 to 2019. Explain why you chose to graph them the way that you did.

# %% [markdown]
# **Questions**
#
# Redo and improve the following figure.
#
# Data can be found there:
# https://opendata.paris.fr/explore/dataset/comptage-velo-donnees-compteurs/dataviz/?disjunctive.id_compteur&disjunctive.nom_compteur&disjunctive.id&disjunctive.name

# %%
from google.colab import files
uploaded = files.upload()
from IPython.display import Image

# %%
Image('velib.png')

# %% [markdown]
# **Questions**
#
# Redo and improve the following figure.
#
# https://www.gapminder.org/fw/world-health-chart/whc2019/
#
# For the data, go there:
#
# https://www.gapminder.org/data/

# %% [markdown]
# **Bonus Questions**
#
# Redo and improve the following figure.
#
# http://www.nytimes.com/imagepages/2007/07/29/health/29cancer.graph.web.html

# %%
# Author: Nicolas P. Rougier

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# ----------
# Data to be represented
diseases = [
    "Kidney Cancer",
    "Bladder Cancer",
    "Esophageal Cancer",
    "Ovarian Cancer",
    "Liver Cancer",
    "Non-Hodgkin's\nlymphoma",
    "Leukemia",
    "Prostate Cancer",
    "Pancreatic Cancer",
    "Breast Cancer",
    "Colorectal Cancer",
    "Lung Cancer",
]
men_deaths = [
    10000,
    12000,
    13000,
    0,
    14000,
    12000,
    16000,
    25000,
    20000,
    500,
    25000,
    80000,
]
men_cases = [
    30000,
    50000,
    13000,
    0,
    16000,
    30000,
    25000,
    220000,
    22000,
    600,
    55000,
    115000,
]
women_deaths = [
    6000,
    5500,
    5000,
    20000,
    9000,
    12000,
    13000,
    0,
    19000,
    40000,
    30000,
    70000,
]
women_cases = [
    20000,
    18000,
    5000,
    25000,
    9000,
    29000,
    24000,
    0,
    21000,
    160000,
    55000,
    97000,
]

# ----------
# Choose some nice colors
matplotlib.rc("axes", facecolor="white")
matplotlib.rc("figure.subplot", wspace=0.65)
matplotlib.rc("grid", color="white")
matplotlib.rc("grid", linewidth=1)

# Make figure background the same colors as axes
fig = plt.figure(figsize=(12, 7), facecolor="white")


# ---WOMEN data ---
axes_left = plt.subplot(121)

# Keep only top and right spines
axes_left.spines["left"].set_color("none")
axes_left.spines["right"].set_zorder(10)
axes_left.spines["bottom"].set_color("none")
axes_left.xaxis.set_ticks_position("top")
axes_left.yaxis.set_ticks_position("right")
axes_left.spines["top"].set_position(("data", len(diseases) + 0.25))
axes_left.spines["top"].set_color("w")

# Set axes limits
plt.xlim(200000, 0)
plt.ylim(0, len(diseases))

# Set ticks labels
plt.xticks([150000, 100000, 50000, 0], ["150,000", "100,000", "50,000", "WOMEN"])
axes_left.get_xticklabels()[-1].set_weight("bold")
axes_left.get_xticklines()[-1].set_markeredgewidth(0)
for label in axes_left.get_xticklabels():
    label.set_fontsize(10)
plt.yticks([])


# Plot data
for i in range(len(women_deaths)):
    H, h = 0.8, 0.55
    # Death
    value = women_cases[i]
    p = patches.Rectangle(
        (0, i + (1 - H) / 2.0),
        value,
        H,
        fill=True,
        transform=axes_left.transData,
        lw=0,
        facecolor="red",
        alpha=0.1,
    )
    axes_left.add_patch(p)
    # New cases
    value = women_deaths[i]
    p = patches.Rectangle(
        (0, i + (1 - h) / 2.0),
        value,
        h,
        fill=True,
        transform=axes_left.transData,
        lw=0,
        facecolor="red",
        alpha=0.5,
    )
    axes_left.add_patch(p)

# Add a grid
axes_left.grid()

plt.text(165000, 8.2, "Leading Causes\nOf Cancer Deaths", fontsize=18, va="top")
plt.text(
    165000,
    7,
    """In 2007, there were more\n"""
    """than 1.4 million new cases\n"""
    """of cancer in the United States.""",
    va="top",
    fontsize=10,
)

# --- MEN data ---
axes_right = plt.subplot(122, sharey=axes_left)

# Keep only top and left spines
axes_right.spines["right"].set_color("none")
axes_right.spines["left"].set_zorder(10)
axes_right.spines["bottom"].set_color("none")
axes_right.xaxis.set_ticks_position("top")
axes_right.yaxis.set_ticks_position("left")
axes_right.spines["top"].set_position(("data", len(diseases) + 0.25))
axes_right.spines["top"].set_color("w")


# Set axes limits
plt.xlim(0, 200000)
plt.ylim(0, len(diseases))

# Set ticks labels
plt.xticks(
    [0, 50000, 100000, 150000, 200000],
    ["MEN", "50,000", "100,000", "150,000", "200,000"],
)
axes_right.get_xticklabels()[0].set_weight("bold")
for label in axes_right.get_xticklabels():
    label.set_fontsize(10)
axes_right.get_xticklines()[1].set_markeredgewidth(0)
plt.yticks([])

# Plot data
for i in range(len(men_deaths)):
    H, h = 0.8, 0.55
    # Death
    value = men_cases[i]
    p = patches.Rectangle(
        (0, i + (1 - H) / 2.0),
        value,
        H,
        fill=True,
        transform=axes_right.transData,
        lw=0,
        facecolor="blue",
        alpha=0.1,
    )
    axes_right.add_patch(p)
    # New cases
    value = men_deaths[i]
    p = patches.Rectangle(
        (0, i + (1 - h) / 2.0),
        value,
        h,
        fill=True,
        transform=axes_right.transData,
        lw=0,
        facecolor="blue",
        alpha=0.5,
    )
    axes_right.add_patch(p)

# Add a grid
axes_right.grid()

# Y axis labels
# We want them to be exactly in the middle of the two y spines
# and it requires some computations
for i in range(len(diseases)):
    x1, y1 = axes_left.transData.transform_point((0, i + 0.5))
    x2, y2 = axes_right.transData.transform_point((0, i + 0.5))
    x, y = fig.transFigure.inverted().transform_point(((x1 + x2) / 2, y1))
    plt.text(
        x,
        y,
        diseases[i],
        transform=fig.transFigure,
        fontsize=10,
        horizontalalignment="center",
        verticalalignment="center",
    )


# Devil hides in the details...
arrowprops = dict(arrowstyle="-", connectionstyle="angle,angleA=0,angleB=90,rad=0")
x = women_cases[-1]
axes_left.annotate(
    "NEW CASES",
    xy=(0.9 * x, 11.5),
    xycoords="data",
    horizontalalignment="right",
    fontsize=10,
    xytext=(-40, -3),
    textcoords="offset points",
    arrowprops=arrowprops,
)

x = women_deaths[-1]
axes_left.annotate(
    "DEATHS",
    xy=(0.85 * x, 11.5),
    xycoords="data",
    horizontalalignment="right",
    fontsize=10,
    xytext=(-50, -25),
    textcoords="offset points",
    arrowprops=arrowprops,
)

x = men_cases[-1]
axes_right.annotate(
    "NEW CASES",
    xy=(0.9 * x, 11.5),
    xycoords="data",
    horizontalalignment="left",
    fontsize=10,
    xytext=(+40, -3),
    textcoords="offset points",
    arrowprops=arrowprops,
)

x = men_deaths[-1]
axes_right.annotate(
    "DEATHS",
    xy=(0.9 * x, 11.5),
    xycoords="data",
    horizontalalignment="left",
    fontsize=10,
    xytext=(+50, -25),
    textcoords="offset points",
    arrowprops=arrowprops,
)
# Out:
# Text(50, -25, 'DEATHS')
